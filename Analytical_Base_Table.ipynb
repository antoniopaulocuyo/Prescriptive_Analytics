# %% [markdown]
# ## **Imports & Loading CSV**

# %%
import pandas as pd

air_quality_path = "Datasets/ph_air_quality_full.csv"
area_density_path = "Datasets/Population_LandArea_Density_Province.csv"
station_province_path = "Datasets/stations_city_province-stations.csv"


df_air_quality = pd.read_csv(air_quality_path)
df_area_density = pd.read_csv(area_density_path)
df_station_province = pd.read_csv(station_province_path)

# %% [markdown]
# ## **Data Inspection**

# %%
print(df_air_quality.head(10))
print(df_area_density.head(10))
print(df_station_province.head(10))
# Out:
#      station  location_id  sensor_id parameter      lat       lon  \
# 0  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 1  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 2  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 3  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 4  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 5  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 6  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 7  313_Cubao      5963700   14249763       pm1  14.6227  121.0528
# 8  313_Cubao      5963700   14249764      pm25  14.6227  121.0528
# 9  313_Cubao      5963700   14249764      pm25  14.6227  121.0528
#
#                 datetime_utc      value   unit
# 0  2025-09-30 07:00:00+00:00   9.001000  µg/m³
# 1  2025-09-30 22:00:00+00:00  34.000000  µg/m³
# 2  2025-09-30 23:00:00+00:00  27.805894  µg/m³
# 3  2025-10-01 00:00:00+00:00  20.776083  µg/m³
# 4  2025-10-01 01:00:00+00:00  20.805986  µg/m³
# 5  2025-10-01 02:00:00+00:00  11.475625  µg/m³
# 6  2025-10-01 03:00:00+00:00   3.681472  µg/m³
# 7  2025-10-01 04:00:00+00:00   0.000000  µg/m³
# 8  2025-09-30 07:00:00+00:00  19.652000  µg/m³
# 9  2025-09-30 22:00:00+00:00  52.500000  µg/m³
#    Region and Province  Population Land area (sq. km.) a1/a2/a3  \
# 0                  NCR  14,001,751                       619.54
# 1                 Abra     246,948                     4,199.72
# 2              Apayao      126,587                     4,502.33
# 3            Benguet i     473,190                     2,769.08
# 4               Ifugao     208,668                     2,618.01
# 5            Kalinga       235,391                     3,282.04
# 6    Mountain Province     149,775                     2,389.43
# 7         Ilocos Norte     618,850                     3,418.75
# 8           Ilocos Sur     709,991                     2,596.00
# 9             La Union     825,072                     1,499.28
#
#   Density (persons/ sq km)
# 0                   21,765
# 1                       60
# 2                       28
# 3                      166
# 4                       79
# 5                       70
# 6                       66
# 7                      178
# 8                      272
# 9                      548
#                                      station       lat        lon  \
# 0                                  313_Cubao  14.62270  121.05280
# 1                        3S Center Bagbaguin  14.71405  121.00088
# 2                     3S Center Paso De Blas  14.71071  120.99545
# 3                            3S Center Ugong  14.69397  121.00919
# 4                       ADB Courtyard (Demo)  14.58828  121.05896
# 5                                      ASMPH  14.59083  121.07037
# 6                           Along Shaw Blvd.  14.57863  121.05675
# 7                                Anda Circle  14.59064  120.97112
# 8  Aurora Boulevard (Tramo) - Andrews Avenue  14.52904  121.00472
# 9                                 Ayala Ave.  14.55612  121.02236
#
#           city province
# 0       Quezon      NCR
# 1   Valenzuela      NCR
# 2   Valenzuela      NCR
# 3   Valenzuela      NCR
# 4  Mandaluyong      NCR
# 5        Pasig      NCR
# 6  Mandaluyong      NCR
# 7       Manila      NCR
# 8        Pasay      NCR
# 9       Makati      NCR

# %%
for col in df_air_quality.columns:
    print(f'Unique values for {col}: {df_air_quality[col].unique()}')
    print("-" * 100)
# Out:
# Unique values for station: <ArrowStringArray>
# [                                                                              '313_Cubao',
#                                                                      '3S Center Bagbaguin',
#                                                                   '3S Center Paso De Blas',
#                                                                          '3S Center Ugong',
#                                                                     'ADB Courtyard (Demo)',
#                                                                                    'ASMPH',
#                                                                         'Along Shaw Blvd.',
#                                                                              'Anda Circle',
#                                                'Aurora Boulevard (Tramo) - Andrews Avenue',
#                                                                               'Ayala Ave.',
#                                                                                'Ayala MRT',
#                                                         'Bacolod City Araneta-Hernaez Sts',
#                                                        'Bacolod City San Juan-Gonzaga Sts',
#                                                        'Barangay Buli - Concepcion Street',
#                                                         'Barangay Fortune - Santan Street',
#                                   'Barangay San Antonio - Parañaque-Sucat Road (Shopwise)',
#                                                                 'Barangay San Rafael Hall',
#                                                          'Barangay Tambo - Quirino Avenue',
#                                                                    'Barangay Tanza 2 Hall',
#                              'Barangay Tunasan - Maharlika Highway (SM Center Muntinlupa)',
#                                                                      'Bataan Tourism Park',
#                                                                               'Binangonan',
#                                                             'Bo. Luz Barangay Hall, Limay',
#                                                                             'Boni Serrano',
#                                                                'Bradco Ave. cor Macapagal',
#                                                                         'Brgy. Ambassador',
#                                                            'Brgy. Benedicto, Jaro, Iloilo',
#                                                                  'Brgy. East Timawa, Molo',
#                                                                            'Brgy. Infante',
#                                            'C3 Road (5th Avenue) - Rizal Avenue Extension',
#                                                                  'Caloocan Sports Complex',
#                                                            'Central Philippine University',
#                                                                     'DENR Compound Parola',
#                                                                              'DLSU Laguna',
#                                                         'Daet, Camarines Norte (Roadside)',
#                                                                              'Demo Unit 1',
#                                                                              'Demo Unit 2',
#                                                                              'Demo Unit 4',
#                                                   'Gen. Luna St. corner Gov. Pascual Ave.',
#                                                                                 'Illumina',
#                                                       'Iloilo City, Augustine Grove Subd.',
#                                                           'J.P. Rizal Avenue corner Camia',
#                                                       'J.P. Rizal Avenue corner Pertierra',
#                                             'Kalayaan Avenue  - South Avenue Intersection',
#                                                                             'Lamao, Limay',
#                                                                           'Lapu-Lapu City',
#                                                                                'Las Pinas',
#                                                                          'MNHS AQ Station',
#                                      'Makati Avenue  - Antonio Arnaiz Avenue Intersection',
#                                              'Makati Avenue - Buendia Avenue Intersection',
#                                                                    'Malabon Action Center',
#                                                                      'Mall of Asia Sensor',
#                                                                         'Mandaluyong City',
#                                                            'Mandaluyong Elementary School',
#                                                                                   'Manila',
#                                                                       'Manila Observatory',
#                                                                                 'Marikina',
#                                                                  'Marikina Sports Complex',
#                                                                 'Mariveles Municipal Hall',
#                                                                      'Monumento, Caloocan',
#                                                             'NASA GSFC Rutgers Calib. N12',
#                                                         'Near Katipunan Ave., Quezon City',
#                                                                    'Near Puregold Tayuman',
#                                                              'Near Sucat Interchange/Exit',
#  'North Caloocan Nova Romania - Alora (download airgradient mobile app for realtime data)',
#                                                 'Old Wack Wack Road corner Shaw Boulevard',
#                                                                                  'Ortigas',
#                                                    'Ortigas Avenue-Roosevelt Intersection',
#                                                                            'Pasay Rotonda',
#                                                                               'Pasay-Taft',
#                                                                           'Pateros Bridge',
#                                                                               'Pinya Farm',
#                                                                          'President Roxas',
#                                                                     'Quezon Rd, San Simon',
# Unique values for datetime_utc: <ArrowStringArray>
# ['2025-09-30 07:00:00+00:00', '2025-09-30 22:00:00+00:00',
#  '2025-09-30 23:00:00+00:00', '2025-10-01 00:00:00+00:00',
#  '2025-10-01 01:00:00+00:00', '2025-10-01 02:00:00+00:00',
#  '2025-10-01 03:00:00+00:00', '2025-10-01 04:00:00+00:00',
#  '2025-06-19 18:01:39+00:00', '2025-06-19 18:18:38+00:00',
#  ...
#  '2026-03-07 17:15:30+00:00', '2026-03-07 17:33:20+00:00',
#  '2026-03-07 17:51:09+00:00', '2026-03-07 18:08:59+00:00',
#  '2026-03-07 18:26:45+00:00', '2026-03-07 18:44:31+00:00',
#  '2026-03-07 19:02:20+00:00', '2026-03-07 19:20:10+00:00',
#  '2026-03-07 19:37:56+00:00', '2026-03-07 19:55:43+00:00']
# Length: 912848, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values for value: [  9.00099996  34.          27.80589379 ... 144.03       109.28
#  127.03      ]
# ----------------------------------------------------------------------------------------------------
# Unique values for unit: <ArrowStringArray>
# ['µg/m³', '%', 'c', 'particles/cm³']
# Length: 4, dtype: str
# ----------------------------------------------------------------------------------------------------

# %%
for col in df_area_density.columns:
    print(f'Unique values for {col}: {df_area_density[col].unique()}')
    print("-" * 100)
# Out:
# Unique values for Region and Province: <ArrowStringArray>
# [                                    'NCR',
#                                    ' Abra',
#                                '  Apayao ',
#                              '  Benguet i',
#                                 '  Ifugao',
#                              '  Kalinga  ',
#                      '  Mountain Province',
#                           '  Ilocos Norte',
#                             '  Ilocos Sur',
#                               '  La Union',
#                             '  Pangasinan',
#                                '  Batanes',
#                                '  Cagayan',
#                                '  Isabela',
#                         '  Nueva Vizcaya ',
#                                '  Quirino',
#                                '  Aurora ',
#                                 '  Bataan',
#                               '  Bulacan ',
#                            '  Nueva Ecija',
#                             '  Pampanga i',
#                                 '  Tarlac',
#                             '  Zambales i',
#                               '  Batangas',
#                                 '  Cavite',
#                                 '  Laguna',
#                               '  Quezon i',
#                                 '  Rizal ',
#                             '  Marinduque',
#                     '  Occidental Mindoro',
#                       '  Oriental Mindoro',
#                              '  Palawan i',
#                                '  Romblon',
#                                  '  Albay',
#                        '  Camarines Norte',
#                          '  Camarines Sur',
#                            '  Catanduanes',
#                                '  Masbate',
#                               '  Sorsogon',
#                                  '  Aklan',
#                                '  Antique',
#                                  '  Capiz',
#                             '  Guimaras  ',
#                               '  Iloilo i',
#                    'Negros Occidental 1,i',
#             'Negros Island Region (NIR) 6',
#                        'Negros Oriental 8',
#                               'Siquijor 8',
#                                  '  Bohol',
#                                 '  Cebu i',
#                        'Negros Oriental 1',
#                               '  Siquijor',
#                              '  Biliran  ',
#                          '  Eastern Samar',
#                                '  Leyte i',
#                         '  Northern Samar',
#                  '  Samar (Western Samar)',
#                         '  Southern Leyte',
#                    '  Zamboanga del Norte',
#                    '  Zamboanga del Sur i',
#                      '  Zamboanga Sibugay',
#                               '  Bukidnon',
#                               '  Camiguin',
#                      '  Lanao del Norte i',
#                     '  Misamis Occidental',
#                     '  Misamis Oriental i',
#       'Davao De Oro (Compostela Valley) 2',
#                        '  Davao del Norte',
#                        '  Davao del Sur i',
#                       '  Davao Occidental',
#                         '  Davao Oriental',
#         '  Cotabato (North Cotabato)     ',
#                              '  Sarangani',
#                       '  South Cotabato i',
#                         '  Sultan Kudarat',
#                     '  Agusan del Norte i',
#                         '  Agusan del Sur',
#                        '  Dinagat Islands',
#                      '  Surigao del Norte',
#                        '  Surigao del Sur',
#    '  Basilan (excluding City of Isabela)',
#                          '  Lanao del Sur',
#  '  Maguindanao (excluding Cotabato City)',
#                  'Maguindanao Del Norte 9',
#                    'Maguindanao Del Sur 9',
#                                   '  Sulu',
#                              '  Tawi-Tawi']
# Length: 87, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values for Population: <ArrowStringArray>
# ['14,001,751',    '246,948',    '126,587',    '473,190',    '208,668',
#     '235,391',    '149,775',    '618,850',    '709,991',    '825,072',
#   '3,188,540',     '18,937',  '1,284,676',  '1,733,048',    '530,106',
#     '210,841',    '240,824',    '891,440',  '3,876,806',  '2,395,816',
#   '2,586,446',  '1,568,162',    '681,225',  '2,994,795',  '4,573,884',
#   '3,687,345',  '1,980,338',  '3,416,541',    '226,522',    '511,417',
#     '919,504',    '968,795',    '302,824',  '1,379,398',    '604,666',
#   '2,063,314',    '261,169',    '910,813',    '845,066',    '634,422',
#     '643,173',    '835,098',    '192,874',  '2,082,616',  '2,680,477',
#   '4,904,944',  '1,492,038',    '107,642',  '1,412,726',  '3,400,522',
#           '…',    '184,095',    '472,683',  '1,823,458',    '645,789',
#     '806,179',    '434,372',  '1,067,067',  '1,045,126',    '661,498',
#   '1,601,902',     '94,892',    '761,725',    '621,993',    '988,065',
#     '783,775',  '1,143,931',    '705,129',    '317,598',    '590,042',
#   '1,286,142',    '580,915',  '1,010,009',    '863,651',    '404,100',
#     '740,531',    '120,533',    '565,644',    '648,858',    '541,947',
#   '1,368,137',  '1,124,811',    '813,243',  '1,146,097',    '482,645']
# Length: 85, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values for Land area (sq. km.) a1/a2/a3: <ArrowStringArray>
# [   '619.54',  '4,199.72',  '4,502.33',  '2,769.08',  '2,618.01',  '3,282.04',
#   '2,389.43',  '3,418.75',  '2,596.00',  '1,499.28',  '5,450.59',    '203.22',
#   '9,398.07', '13,102.05',  '4,813.88',  '2,319.66',  '3,133.40',  '1,372.98',
#   '2,783.69',  '5,689.69',  '2,001.22',  '3,046.49',  '3,630.35',  '3,115.05',
#   '1,526.28',  '1,928.23',  '8,743.84',  '1,182.65',    '952.58',  '5,851.09',
#   '4,238.38', '14,649.73',  '1,533.45',  '2,574.91',  '2,277.93',  '5,511.90',
#   '1,492.16',  '4,138.56',  '2,119.01',  '1,760.30',  '2,730.67',  '2,594.64',
#     '611.87',  '4,997.64',  '7,844.12',         '…',  '4,772.52',  '4,943.72',
#   '5,420.57',    '337.49',    '536.01',  '4,617.16',  '6,335.44',  '3,694.96',
#   '6,048.03',  '1,801.46',  '7,300.11',  '4,484.21',  '3,481.28', '10,498.59',
#     '241.44',  '3,354.16',  '2,006.63',  '3,131.52',  '4,560.09',  '3,422.61',
#   '2,163.98',  '2,163.45',  '5,679.64',  '9,317.30',  '3,642.16',  '3,793.90',
#   '5,363.86',  '2,611.63',  '9,989.52',    '817.47',  '1,952.62',  '4,932.70',
#   '3,453.42', '15,055.51',  '9,968.31',  '4,547.16',  '3,626.55']
# Length: 83, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values for Density (persons/ sq km): <ArrowStringArray>
# ['21,765',     '60',     '28',    '166',     '79',     '70',     '66',
#     '178',    '272',    '548',    '580',     '93',    '135',    '130',
#     '103',     '88',     '75',    '622',  '1,332',    '406',  '1,218',
#     '494',    '179',    '934',  '2,847',  '1,754',    '223',  '2,816',
#     '251',     '90',    '214',     '64',    '201',    '534',    '276',
#     '375',    '182',    '220',    '391',    '350',    '224',    '310',
#     '307',    '411',    '334',      '…',    '292',    '673',    '264',
#     '306',    '335',    '280',    '173',    '131',    '238',    '143',
#     '234',    '192',    '147',    '384',    '216',    '308',    '168',
#     '329',    '314',    '101',    '160',    '153',    '257',    '159',
#     '148',     '74',    '157',    '274',    '123',    '121']
# Length: 76, dtype: str
# ----------------------------------------------------------------------------------------------------

# %%
for col in df_station_province.columns:
    print(f'Unique values for {col}: {df_station_province[col].unique()}')
    print("-" * 100)
# Out:
# Unique values for station: <ArrowStringArray>
# [                                                                              '313_Cubao',
#                                                                      '3S Center Bagbaguin',
#                                                                   '3S Center Paso De Blas',
#                                                                          '3S Center Ugong',
#                                                                     'ADB Courtyard (Demo)',
#                                                                                    'ASMPH',
#                                                                         'Along Shaw Blvd.',
#                                                                              'Anda Circle',
#                                                'Aurora Boulevard (Tramo) - Andrews Avenue',
#                                                                               'Ayala Ave.',
#                                                                                'Ayala MRT',
#                                                         'Bacolod City Araneta-Hernaez Sts',
#                                                        'Bacolod City San Juan-Gonzaga Sts',
#                                                        'Barangay Buli - Concepcion Street',
#                                                         'Barangay Fortune - Santan Street',
#                                   'Barangay San Antonio - Parañaque-Sucat Road (Shopwise)',
#                                                                 'Barangay San Rafael Hall',
#                                                          'Barangay Tambo - Quirino Avenue',
#                                                                    'Barangay Tanza 2 Hall',
#                              'Barangay Tunasan - Maharlika Highway (SM Center Muntinlupa)',
#                                                                      'Bataan Tourism Park',
#                                                                               'Binangonan',
#                                                             'Bo. Luz Barangay Hall, Limay',
#                                                                             'Boni Serrano',
#                                                                'Bradco Ave. cor Macapagal',
#                                                                         'Brgy. Ambassador',
#                                                            'Brgy. Benedicto, Jaro, Iloilo',
#                                                                  'Brgy. East Timawa, Molo',
#                                                                            'Brgy. Infante',
#                                            'C3 Road (5th Avenue) - Rizal Avenue Extension',
#                                                                  'Caloocan Sports Complex',
#                                                            'Central Philippine University',
#                                                                     'DENR Compound Parola',
#                                                                              'DLSU Laguna',
#                                                         'Daet, Camarines Norte (Roadside)',
#                                                                              'Demo Unit 1',
#                                                                              'Demo Unit 2',
#                                                                              'Demo Unit 4',
#                                                   'Gen. Luna St. corner Gov. Pascual Ave.',
#                                                                                 'Illumina',
#                                                       'Iloilo City, Augustine Grove Subd.',
#                                                           'J.P. Rizal Avenue corner Camia',
#                                                       'J.P. Rizal Avenue corner Pertierra',
#                                             'Kalayaan Avenue  - South Avenue Intersection',
#                                                                             'Lamao, Limay',
#                                                                           'Lapu-Lapu City',
#                                                                                'Las Pinas',
#                                                                          'MNHS AQ Station',
#                                      'Makati Avenue  - Antonio Arnaiz Avenue Intersection',
#                                              'Makati Avenue - Buendia Avenue Intersection',
#                                                                    'Malabon Action Center',
#                                                                      'Mall of Asia Sensor',
#                                                                         'Mandaluyong City',
#                                                            'Mandaluyong Elementary School',
#                                                                                   'Manila',
#                                                                       'Manila Observatory',
#                                                                                 'Marikina',
#                                                                  'Marikina Sports Complex',
#                                                                 'Mariveles Municipal Hall',
#                                                                      'Monumento, Caloocan',
#                                                             'NASA GSFC Rutgers Calib. N12',
#                                                         'Near Katipunan Ave., Quezon City',
#                                                                    'Near Puregold Tayuman',
#                                                              'Near Sucat Interchange/Exit',
#  'North Caloocan Nova Romania - Alora (download airgradient mobile app for realtime data)',
#                                                 'Old Wack Wack Road corner Shaw Boulevard',
#                                                                                  'Ortigas',
#                                                    'Ortigas Avenue-Roosevelt Intersection',
#                                                                            'Pasay Rotonda',
#                                                                               'Pasay-Taft',
#                                                                           'Pateros Bridge',
#                                                                               'Pinya Farm',
#                                                                          'President Roxas',
#                                                                     'Quezon Rd, San Simon',
#                                                                              'Quezon Road',
#                                                                      'Rajah Sulayman Park',
#                                                               'Ramon Avancena High School',
#                                                      'Robinson's Equitable Tower (Indoor)',
#                                                                                     'STRC',
#                                                                     'Samal Municipal Hall',
#                                             'San Antonio, Los Banos, Laguna (Residential)',
#                                                                       'San Juan Mini Park',
#                                                                 'San Sebastian Residences',
#                                                'Santa Clara - Pasay City General Hospital',
#                                                                                 'Sensor 1',
#                                                              'South Triangle, Quezon City',
#                                                                        'Sta. Ana Hospital',
#                                                                      'Sto. Rosario Bridge',
#                                                                      'Tagaytay (Neogan 2)',
#                                                                        'Tagaytay (Neogan)',
#                                                      'Timoteo Paez Integrated High School',
#                                                                                   'Tivoli',
#                                                           'Unnamed (DNVBA1576 → AL739RG7)',
#                                                                               'Valenzuela',
#                                                            'Valenzuela CENRO (ARCA North)',
#                                                                                   'Valle1',
#                                                                       'World Trade Center',
#                                                                               'pasay city']
# Length: 98, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values for lat: [14.6227     14.71405    14.71071    14.69397    14.58828    14.59083
#  14.57863    14.59064    14.52904    14.55612    14.5496     10.6635921
#  10.6694049  14.44481    14.66115    14.45671    14.63666    14.51769
#  14.67508    14.37853    14.67759    14.5235999  14.5507     14.61071
#  14.52917    16.49742018 10.7258204  10.696736   10.6941494  14.64443
#  14.75097    10.73146968 10.69402521 14.26266    14.1157     14.58594
#  15.0247     15.19384    14.66963     7.143752   10.73536978 14.56746
#  14.56838    14.5688     14.515      10.32645    14.437546   10.99814
#  14.56127    14.66916    14.536036   14.58455    14.58655    14.57711
#  14.6354     14.65568    14.6341     14.436      14.65744    14.63525
#  14.63842    14.61825    14.45627    14.7459495  14.58734    14.58853
#  14.60346    14.53766    14.5377     14.5457     14.143177   11.43032
#  15.00045    14.99976    14.569      14.593565   14.58944    14.56637518
#  14.76944    14.17488    14.60399    14.59871    14.54848    14.639479
#  14.58385    14.54939    14.098141   14.095018   14.630765   14.676664
#  14.56383    14.688555   14.69158    14.576655   14.55157    14.558248  ]
# ----------------------------------------------------------------------------------------------------
# Unique values for lon: [121.0528    121.00088   120.99545   121.00919   121.05896   121.07037
#  121.05675   120.97112   121.00472   121.02236   121.0285    122.9434386
#  122.9453514 121.04586   121.12476   121.03519   120.96414   120.99638
#  120.93989   121.04615   120.5182    121.1645249 120.5975    121.05484
#  120.98988   120.6534127 122.5580665 122.5488203 122.5551708 120.98409
#  121.02042   122.546953  122.580963  121.04338   122.9551    121.02932
#  120.68723   120.63862   120.94676   125.625054  122.537027  121.03929
#  121.02845   121.01795   120.609     123.97871   121.000088  125.64968
#  121.02221   121.02799   120.97576   120.985543  121.01877   121.02549
#  120.9778    121.0779    121.11149   121.09803   120.4903    120.98362
#  121.07784   121.0767    120.97142   121.04569   121.0101457 121.04665
#  121.05822   121.04448   121.00039   121.00094   121.06514   120.984941
#  122.926229  120.7505    120.75153   120.98366   120.989459  121.05978
#  120.9922368 120.54278   121.24649   121.02781   120.98947   121.00053
#  121.0827    121.032469  121.01645   121.07264   120.892358  120.895382
#  120.967483  121.095814  121.05797   120.970708  120.97246   121.070464
#  120.98649   120.993386 ]
# ----------------------------------------------------------------------------------------------------
# Unique values for city: <ArrowStringArray>
# [         'Quezon',      'Valenzuela',     'Mandaluyong',           'Pasig',
#           'Manila',           'Pasay',          'Makati',         'Bacolod',
#       'Muntinlupa',        'Marikina',       'Parañaque',         'Navotas',
#          'Balanga',      'Binangonan',           'Limay',          'Tublay',
#           'Iloilo',        'Caloocan',           'Biñan',            'Daet',
#     'San Fernando',        'Magalang',         'Malabon',           'Davao',
#        'Lapu-Lapu',       'Las Piñas',         'Guiuan ',       'Mariveles',
#         'San Juan',          'Taguig',          'Silang', 'President Roxas',
#        'San Simon',           'Samal',       'Los Baños',         'Pateros',
#         'Tagaytay']
# Length: 37, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values for province: <ArrowStringArray>
# [              'NCR', 'Negros Occidental',            'Bataan',
#              'Rizal',           'Benguet',            'Iloilo',
#             'Laguna',   'Camarines Norte',          'Pampanga',
#      'Davao del Sur',              'Cebu',     'Eastern Samar',
#             'Cavite',             'Capiz']
# Length: 14, dtype: str
# ----------------------------------------------------------------------------------------------------

# %%
print(df_air_quality.columns)
print(df_area_density.columns)
print(df_station_province.columns)
# Out:
# Index(['station', 'location_id', 'sensor_id', 'parameter', 'lat', 'lon',
#        'datetime_utc', 'value', 'unit'],
#       dtype='str')
# Index(['Region and Province', 'Population', 'Land area (sq. km.) a1/a2/a3',
#        'Density (persons/ sq km)'],
#       dtype='str')
# Index(['station', 'lat', 'lon', 'city', 'province'], dtype='str')

# %% [markdown]
# Problem 1:
# Formatting of Provinces in `df_area_density` does not exactly match that of `df_station_province`
#
# Implemented Solution for Problem 1:
# 1) Extract the necessary values needed in `df_stations_province`
# 2) Extract the equivalent values into a new file `df_area_density_prod`
# 3) Modify only `df_area_density_prod`
# 4) Merge into `Analytical Base Table`

# %% [markdown]
# ## **Analytical Base Table**

# %%
province_list = df_station_province["province"].unique()
for province in province_list:
    province.strip()
print(province_list)
# Out:
# <ArrowStringArray>
# [              'NCR', 'Negros Occidental',            'Bataan',
#              'Rizal',           'Benguet',            'Iloilo',
#             'Laguna',   'Camarines Norte',          'Pampanga',
#      'Davao del Sur',              'Cebu',     'Eastern Samar',
#             'Cavite',             'Capiz']
# Length: 14, dtype: str

# %%
df_area_density_prod = df_area_density.copy()

df_area_density_prod['Region and Province'] = df_area_density_prod['Region and Province'].str.strip()
print(df_area_density_prod['Region and Province'].unique())
# Out:
# <ArrowStringArray>
# [                                  'NCR',
#                                   'Abra',
#                                 'Apayao',
#                              'Benguet i',
#                                 'Ifugao',
#                                'Kalinga',
#                      'Mountain Province',
#                           'Ilocos Norte',
#                             'Ilocos Sur',
#                               'La Union',
#                             'Pangasinan',
#                                'Batanes',
#                                'Cagayan',
#                                'Isabela',
#                          'Nueva Vizcaya',
#                                'Quirino',
#                                 'Aurora',
#                                 'Bataan',
#                                'Bulacan',
#                            'Nueva Ecija',
#                             'Pampanga i',
#                                 'Tarlac',
#                             'Zambales i',
#                               'Batangas',
#                                 'Cavite',
#                                 'Laguna',
#                               'Quezon i',
#                                  'Rizal',
#                             'Marinduque',
#                     'Occidental Mindoro',
#                       'Oriental Mindoro',
#                              'Palawan i',
#                                'Romblon',
#                                  'Albay',
#                        'Camarines Norte',
#                          'Camarines Sur',
#                            'Catanduanes',
#                                'Masbate',
#                               'Sorsogon',
#                                  'Aklan',
#                                'Antique',
#                                  'Capiz',
#                               'Guimaras',
#                               'Iloilo i',
#                  'Negros Occidental 1,i',
#           'Negros Island Region (NIR) 6',
#                      'Negros Oriental 8',
#                             'Siquijor 8',
#                                  'Bohol',
#                                 'Cebu i',
#                      'Negros Oriental 1',
#                               'Siquijor',
#                                'Biliran',
#                          'Eastern Samar',
#                                'Leyte i',
#                         'Northern Samar',
#                  'Samar (Western Samar)',
#                         'Southern Leyte',
#                    'Zamboanga del Norte',
#                    'Zamboanga del Sur i',
#                      'Zamboanga Sibugay',
#                               'Bukidnon',
#                               'Camiguin',
#                      'Lanao del Norte i',
#                     'Misamis Occidental',
#                     'Misamis Oriental i',
#     'Davao De Oro (Compostela Valley) 2',
#                        'Davao del Norte',
#                        'Davao del Sur i',
#                       'Davao Occidental',
#                         'Davao Oriental',
#              'Cotabato (North Cotabato)',
#                              'Sarangani',
#                       'South Cotabato i',
#                         'Sultan Kudarat',
#                     'Agusan del Norte i',
#                         'Agusan del Sur',
#                        'Dinagat Islands',
#                      'Surigao del Norte',
#                        'Surigao del Sur',
#    'Basilan (excluding City of Isabela)',
#                          'Lanao del Sur',
#  'Maguindanao (excluding Cotabato City)',
#                'Maguindanao Del Norte 9',
#                  'Maguindanao Del Sur 9',
#                                   'Sulu',
#                              'Tawi-Tawi']
# Length: 87, dtype: str

# %%
df_area_density_prod['Region and Province'] = (
    df_area_density_prod['Region and Province']
    .str.replace(r'\s*\([^)]*\)', '', regex=True)
    .str.replace(r'\s+[0-9,i]+$', '', regex=True)
    .str.replace(r'\s+', ' ', regex=True)
    .str.strip()
)

print(df_area_density_prod['Region and Province'].unique())
# Out:
# <ArrowStringArray>
# [                  'NCR',                  'Abra',                'Apayao',
#                'Benguet',                'Ifugao',               'Kalinga',
#      'Mountain Province',          'Ilocos Norte',            'Ilocos Sur',
#               'La Union',            'Pangasinan',               'Batanes',
#                'Cagayan',               'Isabela',         'Nueva Vizcaya',
#                'Quirino',                'Aurora',                'Bataan',
#                'Bulacan',           'Nueva Ecija',              'Pampanga',
#                 'Tarlac',              'Zambales',              'Batangas',
#                 'Cavite',                'Laguna',                'Quezon',
#                  'Rizal',            'Marinduque',    'Occidental Mindoro',
#       'Oriental Mindoro',               'Palawan',               'Romblon',
#                  'Albay',       'Camarines Norte',         'Camarines Sur',
#            'Catanduanes',               'Masbate',              'Sorsogon',
#                  'Aklan',               'Antique',                 'Capiz',
#               'Guimaras',                'Iloilo',     'Negros Occidental',
#   'Negros Island Region',       'Negros Oriental',              'Siquijor',
#                  'Bohol',                  'Cebu',               'Biliran',
#          'Eastern Samar',                 'Leyte',        'Northern Samar',
#                  'Samar',        'Southern Leyte',   'Zamboanga del Norte',
#      'Zamboanga del Sur',     'Zamboanga Sibugay',              'Bukidnon',
#               'Camiguin',       'Lanao del Norte',    'Misamis Occidental',
#       'Misamis Oriental',          'Davao De Oro',       'Davao del Norte',
#          'Davao del Sur',      'Davao Occidental',        'Davao Oriental',
#               'Cotabato',             'Sarangani',        'South Cotabato',
#         'Sultan Kudarat',      'Agusan del Norte',        'Agusan del Sur',
#        'Dinagat Islands',     'Surigao del Norte',       'Surigao del Sur',
#                'Basilan',         'Lanao del Sur',           'Maguindanao',
#  'Maguindanao Del Norte',   'Maguindanao Del Sur',                  'Sulu',
#              'Tawi-Tawi']
# Length: 85, dtype: str

# %%
analytical_base_table = pd.merge( df_air_quality,
                                  df_station_province,
                                  on= 'station'
                                  )

analytical_base_table.rename(columns={'value': 'pm25 in µg/m^3'}, inplace=True)
analytical_base_table.drop(columns=['location_id',
                                    'sensor_id',
                                    'lon_x',
                                    'lat_y',
                                    'parameter',
                                    'unit'], inplace=True)

# %%
for col in analytical_base_table.columns:
    print(f'Unique values for {col}: {analytical_base_table[col].unique()}')
    print("-" * 100)
# Out:
# Unique values for station: <ArrowStringArray>
# [                                                                              '313_Cubao',
#                                                                      '3S Center Bagbaguin',
#                                                                   '3S Center Paso De Blas',
#                                                                          '3S Center Ugong',
#                                                                     'ADB Courtyard (Demo)',
#                                                                                    'ASMPH',
#                                                                         'Along Shaw Blvd.',
#                                                                              'Anda Circle',
#                                                'Aurora Boulevard (Tramo) - Andrews Avenue',
#                                                                               'Ayala Ave.',
#                                                                                'Ayala MRT',
#                                                         'Bacolod City Araneta-Hernaez Sts',
#                                                        'Bacolod City San Juan-Gonzaga Sts',
#                                                        'Barangay Buli - Concepcion Street',
#                                                         'Barangay Fortune - Santan Street',
#                                   'Barangay San Antonio - Parañaque-Sucat Road (Shopwise)',
#                                                                 'Barangay San Rafael Hall',
#                                                          'Barangay Tambo - Quirino Avenue',
#                                                                    'Barangay Tanza 2 Hall',
#                              'Barangay Tunasan - Maharlika Highway (SM Center Muntinlupa)',
#                                                                      'Bataan Tourism Park',
#                                                                               'Binangonan',
#                                                             'Bo. Luz Barangay Hall, Limay',
#                                                                             'Boni Serrano',
#                                                                'Bradco Ave. cor Macapagal',
#                                                                         'Brgy. Ambassador',
#                                                            'Brgy. Benedicto, Jaro, Iloilo',
#                                                                  'Brgy. East Timawa, Molo',
#                                                                            'Brgy. Infante',
#                                            'C3 Road (5th Avenue) - Rizal Avenue Extension',
#                                                                  'Caloocan Sports Complex',
#                                                            'Central Philippine University',
#                                                                     'DENR Compound Parola',
#                                                                              'DLSU Laguna',
#                                                         'Daet, Camarines Norte (Roadside)',
#                                                                              'Demo Unit 1',
#                                                                              'Demo Unit 2',
#                                                                              'Demo Unit 4',
#                                                   'Gen. Luna St. corner Gov. Pascual Ave.',
#                                                                                 'Illumina',
#                                                       'Iloilo City, Augustine Grove Subd.',
#                                                           'J.P. Rizal Avenue corner Camia',
#                                                       'J.P. Rizal Avenue corner Pertierra',
#                                             'Kalayaan Avenue  - South Avenue Intersection',
#                                                                             'Lamao, Limay',
#                                                                           'Lapu-Lapu City',
#                                                                                'Las Pinas',
#                                                                          'MNHS AQ Station',
#                                      'Makati Avenue  - Antonio Arnaiz Avenue Intersection',
#                                              'Makati Avenue - Buendia Avenue Intersection',
#                                                                    'Malabon Action Center',
#                                                                      'Mall of Asia Sensor',
#                                                                         'Mandaluyong City',
#                                                            'Mandaluyong Elementary School',
#                                                                                   'Manila',
#                                                                       'Manila Observatory',
#                                                                                 'Marikina',
#                                                                  'Marikina Sports Complex',
#                                                                 'Mariveles Municipal Hall',
#                                                                      'Monumento, Caloocan',
#                                                             'NASA GSFC Rutgers Calib. N12',
#                                                         'Near Katipunan Ave., Quezon City',
#                                                                    'Near Puregold Tayuman',
#                                                              'Near Sucat Interchange/Exit',
#  'North Caloocan Nova Romania - Alora (download airgradient mobile app for realtime data)',
#                                                 'Old Wack Wack Road corner Shaw Boulevard',
#                                                                                  'Ortigas',
#                                                    'Ortigas Avenue-Roosevelt Intersection',
#                                                                            'Pasay Rotonda',
#                                                                               'Pasay-Taft',
#                                                                           'Pateros Bridge',
#                                                                               'Pinya Farm',
#                                                                          'President Roxas',
#                                                                     'Quezon Rd, San Simon',
#                                                                      'Rajah Sulayman Park',
#                                                               'Ramon Avancena High School',
#                                                      'Robinson's Equitable Tower (Indoor)',
#                                                                                     'STRC',
#                                                                     'Samal Municipal Hall',
#                                             'San Antonio, Los Banos, Laguna (Residential)',
#                                                                       'San Juan Mini Park',
#                                                                 'San Sebastian Residences',
#                                                'Santa Clara - Pasay City General Hospital',
#                                                                                 'Sensor 1',
#                                                              'South Triangle, Quezon City',
#                                                                        'Sta. Ana Hospital',
#                                                                      'Sto. Rosario Bridge',
#                                                                      'Tagaytay (Neogan 2)',
#                                                                        'Tagaytay (Neogan)',
#                                                      'Timoteo Paez Integrated High School',
#                                                                                   'Tivoli',
#                                                           'Unnamed (DNVBA1576 → AL739RG7)',
#                                                                               'Valenzuela',
#                                                            'Valenzuela CENRO (ARCA North)',
#                                                                                   'Valle1',
#                                                                       'World Trade Center',
#                                                                               'pasay city']
# Length: 97, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values
#          'Balanga',      'Binangonan',           'Limay',          'Tublay',
#           'Iloilo',        'Caloocan',           'Biñan',            'Daet',
#     'San Fernando',        'Magalang',         'Malabon',           'Davao',
#        'Lapu-Lapu',       'Las Piñas',         'Guiuan ',       'Mariveles',
#         'San Juan',          'Taguig',          'Silang', 'President Roxas',
#        'San Simon',           'Samal',       'Los Baños',         'Pateros',
#         'Tagaytay']
# Length: 37, dtype: str
# ----------------------------------------------------------------------------------------------------
# Unique values for province: <ArrowStringArray>
# [              'NCR', 'Negros Occidental',            'Bataan',
#              'Rizal',           'Benguet',            'Iloilo',
#             'Laguna',   'Camarines Norte',          'Pampanga',
#      'Davao del Sur',              'Cebu',     'Eastern Samar',
#             'Cavite',             'Capiz']
# Length: 14, dtype: str
# ----------------------------------------------------------------------------------------------------

# %%
analytical_base_table = pd.merge(analytical_base_table,
                                 df_area_density_prod,
                                 left_on = 'province',
                                 right_on =  'Region and Province',
                                 )

analytical_base_table.drop(columns=['Region and Province'], inplace=True)
analytical_base_table.rename(columns={'Land area (sq. km.) a1/a2/a3': 'area_in_sq.km', 'Density (persons/ sq km)': 'density_persons/sqkm', 'Population': 'population', 'lat_x': 'lat', 'lon_y': 'lon' }, inplace=True)

# %%
print(analytical_base_table.columns
      )
print(analytical_base_table.head(10))
# Out:
# Index(['station', 'lat', 'datetime_utc', 'pm25 in µg/m^3', 'lon', 'city',
#        'province', 'population', 'area_in_sq.km', 'density_persons/sqkm'],
#       dtype='str')
#      station      lat               datetime_utc  pm25 in µg/m^3       lon  \
# 0  313_Cubao  14.6227  2025-09-30 07:00:00+00:00        9.001000  121.0528
# 1  313_Cubao  14.6227  2025-09-30 22:00:00+00:00       34.000000  121.0528
# 2  313_Cubao  14.6227  2025-09-30 23:00:00+00:00       27.805894  121.0528
# 3  313_Cubao  14.6227  2025-10-01 00:00:00+00:00       20.776083  121.0528
# 4  313_Cubao  14.6227  2025-10-01 01:00:00+00:00       20.805986  121.0528
# 5  313_Cubao  14.6227  2025-10-01 02:00:00+00:00       11.475625  121.0528
# 6  313_Cubao  14.6227  2025-10-01 03:00:00+00:00        3.681472  121.0528
# 7  313_Cubao  14.6227  2025-10-01 04:00:00+00:00        0.000000  121.0528
# 8  313_Cubao  14.6227  2025-09-30 07:00:00+00:00       19.652000  121.0528
# 9  313_Cubao  14.6227  2025-09-30 22:00:00+00:00       52.500000  121.0528
#
#      city province  population area_in_sq.km density_persons/sqkm
# 0  Quezon      NCR  14,001,751        619.54               21,765
# 1  Quezon      NCR  14,001,751        619.54               21,765
# 2  Quezon      NCR  14,001,751        619.54               21,765
# 3  Quezon      NCR  14,001,751        619.54               21,765
# 4  Quezon      NCR  14,001,751        619.54               21,765
# 5  Quezon      NCR  14,001,751        619.54               21,765
# 6  Quezon      NCR  14,001,751        619.54               21,765
# 7  Quezon      NCR  14,001,751        619.54               21,765
# 8  Quezon      NCR  14,001,751        619.54               21,765
# 9  Quezon      NCR  14,001,751        619.54               21,765

# %%
analytical_base_table.to_csv("Datasets/analytical_base_table.csv", index=False)

# %%
analytical_base_table.to_parquet("Datasets/analytical_base_table.parquet", index=False)
